# %% [markdown]
# <a href="https://colab.research.google.com/github/kameerahariru/jyanken_baru/blob/ranting_baru/Rock%2C_Paper_%26_Scissors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Player Versus Computer

import random

possibility_1 = "Rock"
possibility_2 = "Paper"
possibility_3 = "Scissors"

print("Let's play Rock, Paper, Scissors!")
print("Rock beats Scissors")
print("Paper beats Rock")
print("Scissors beats Paper")

possibilities = [possibility_1, possibility_2, possibility_3]

player_name = input("What is your name?")
print("Welcome", player_name)

if player not in possibilities:

player = input(print("Choose one of the following: Rock, Paper, Scissors"))
if player not in ("Rock", "Paper", "Scissors"):
    print("Invalid choice, please choose Rock, Paper, or Scissors.")
    return

# Computer choice
Computer = random.choice(possibilities)

print(f"player: {player}")
print(f"Computer: {Computer}")

if player == Computer:
    print("It's a tie!")
elif player == possibility_1 and Computer == possibility_3:
    print("You win!")
elif player == possibility_2 and Computer == possibility_1:
    print("You win!")
elif player == possibility_3 and Computer == possibility_2:
        print("You win!")
else:
        print("You lose!")
# Out:
#   File "<ipython-input-61-4907753c2605>", line 21
#     player = input(print("Choose one of the following: Rock, Paper, Scissors"))
#     ^
# IndentationError: expected an indented block after 'if' statement on line 19

# %%
#Computer1 Versus Computer2

#import statement
import random

#list of candidate
candidate = [candidate_1, candidate_2]

#Variable assignments
candidate_1 = "Computer_1"
candidate_2 = "Computer_2"

#Putting input & the usage of placeholders
print("Welcome to the Prediction Game!")
prediction_game = input("Who do you think is going to win the battle? {} or {}?".format(candidate_1, candidate_2))

# multistrings

possibility_1 = """
            __________
          /         __|
----------          __|
----------          __|
          \         __|
           ___________/
"""
possibility_2 = """
            _____________
          /         _____|____
----------          __________|
----------          ___________|
          \         _________|
            ________________|
"""
possibility_3 = """
            _______
          /        \____________
----------       \  \___________|
----------        \  \__________|
          \   |____\_/___|
           \__|________|
"""

result_1 = "It's a tie!"
result_2 = "Computer_1 win!"
result_3 = "Computer_2 win!"

print("Let's play Rock, Paper, Scissors!")
print("Rock beats Scissors")
print("Paper beats Rock")
print("Scissors beats Paper")

#tuple

possibilities = [possibility_1, possibility_2, possibility_3]

Computer_1 = random.choice(possibilities)
Computer_2 = random.choice(possibilities)

print(f"Computer_1 choose : {Computer_1}")
print(f"Computer_2 choose : {Computer_2}")

if Computer_1 == Computer_2:
    result = result_1
elif Computer_1 == possibility_1 and Computer_2 == possibility_3:
    result = result_2
elif Computer_1 == possibility_2 and Computer_2 == possibility_1:
    result = result_2
elif Computer_1 == possibility_3 and Computer_2 == possibility_2:
    result = result_2
else:
    result = result_3

#boolean, AND & OR function

text_1= f"Your prediction is correct!{prediction_game} is the winner!"
text_2= f"Your prediction is wrong!{prediction_game} is the loser!"
text_3= "It's a tie! Repeat the battle!"

if (prediction_game == candidate_1 and result == result_2) or (prediction_game == candidate_2 and result == result_3):
    print(text_1.upper())
elif result == result_1:
    print(text_3.upper())
else:
    print(text_2.upper())
# Out:
# Welcome to the Prediction Game!
# Who do you think is going to win the battle? Computer_1 or Computer_2?Computer
# Let's play Rock, Paper, Scissors!
# Rock beats Scissors
# Paper beats Rock
# Scissors beats Paper
# Computer_1 choose :
#             __________
#           /         __|
# ----------          __|
# ----------          __|
#           \         __|
#            ___________/
#
# Computer_2 choose :
#             _______
#           /        \____________
# ----------       \  \___________|
# ----------        \  \__________|
#           \   |____\_/___|
#            \__|________|
#
# YOUR PREDICTION IS WRONG!COMPUTER IS THE LOSER!

# %%
#Computer1 Versus Computer2

#import statement

import random

#Making a Blueprint (Defining Class)

class jyankenpoi:
    def __init__(self):
        self.candidate_1 = "computer_1"
        self.candidate_2 = "computer_2"

#list of possibilities (rock, paper & scissors)
        self.possibility_1 = """

            __________
          /         __|
----------          __|
----------          __|
          \         __|
           ___________/

"""
        self.possibility_2 = """

            _____________
          /         _____|____
----------          __________|
----------          ___________|
          \         _________|
            ________________|

"""
        self.possibility_3 = """

            _______
          /        \____________
----------       \  \___________|
----------        \  \__________|
          \   |____\_/___|
           \__|________|

"""

# the battle outcomes
        self.possibilities = [self.possibility_1, self.possibility_2, self.possibility_3]
        self.result_1 = "It's a tie!"
        self.result_2 = "Computer_1 wins!"
        self.result_3 = "Computer_2 wins!"

#while loop, making sure input is not case sensitive
    def get_prediction(self):
        while True:
            print("Welcome to the Prediction Game!")
            prediction_game = input(f"Who do you think is going to win the battle? {self.candidate_1} or {self.candidate_2}? ").strip().lower()

            if prediction_game in [self.candidate_1, self.candidate_2]:
                return prediction_game
            else:
                print("INVALID CHOICE! Please choose between {} or {}.".format(self.candidate_1, self.candidate_2))

#computers making random choices, either rock paper scissors.

    def get_computer_choices(self):
        computer_1 = random.choice(self.possibilities).lower()
        computer_2 = random.choice(self.possibilities).lower()
        return computer_1, computer_2

#determining the winner (if else)
    def determine_winner(self, computer_1, computer_2):
        if computer_1 == computer_2:
            result = self.result_1
        elif computer_1 == self.possibility_1 and computer_2 == self.possibility_3:
            result = self.result_2
        elif computer_1 == self.possibility_2 and computer_2 == self.possibility_1:
            result = self.result_2
        elif computer_1 == self.possibility_3 and computer_2 == self.possibility_2:
            result = self.result_2
        else:
            result = self.result_3
        return result


    def play_game(self):
        prediction_game = self.get_prediction()

        print("Let's play Rock, Paper, Scissors!")
        print("Rock beats Scissors")
        print("Paper beats Rock")
        print("Scissors beats Paper")

#while loop starts, nfinite loop that will continue running until it is being broken
        while True:

            #computer choices
            computer_1, computer_2 = self.get_computer_choices()

            #print choices
            print(f"COMPUTER_1 CHOOSE: {computer_1}")
            print(f"COMPUTER_2 CHOOSE: {computer_2}")

            #determining winner
            result = self.determine_winner(computer_1, computer_2)

            #result messages
            text_1 = f"Your prediction is correct! {prediction_game} is the winner!"
            text_2 = f"Your prediction is wrong! {prediction_game} is the loser!"
            text_3 = "It's a tie! Repeat the battle!"

            #checking prediction (if else)
            if (prediction_game == self.candidate_1 and result == self.result_2) or (prediction_game == self.candidate_2 and result == self.result_3):
                print(text_1.upper())
            elif result == self.result_1:
                print(text_3.upper())
            else:
                print(text_2.upper())

            #play again choice
            play_again = input("Do you want to play again? (yes/no): ").lower()
            if play_again != "yes":
                print("Thanks for playing!")
                break

#This line creates an instance of the jyankenpoi class and assigns it to the variable game.
#The jyankenpoi class likely defines the rules and behavior of the game.

game = jyankenpoi()

#his line calls the play_game method on the game object.
#This method is probably defined within the jyankenpoi class and contains the logic to start or run the game.

game.play_game()
# Out:
# Welcome to the Prediction Game!
# Who do you think is going to win the battle? computer_1 or computer_2? kameera
# INVALID CHOICE! Please choose between computer_1 or computer_2.
# Welcome to the Prediction Game!
# Who do you think is going to win the battle? computer_1 or computer_2? CompuTer_2
# Let's play Rock, Paper, Scissors!
# Rock beats Scissors
# Paper beats Rock
# Scissors beats Paper
# COMPUTER_1 CHOOSE:
#
#             _____________
#           /         _____|____
# ----------          __________|
# ----------          ___________|
#           \         _________|
#             ________________|
#
#
# COMPUTER_2 CHOOSE:
#
#             __________
#           /         __|
# ----------          __|
# ----------          __|
#           \         __|
#            ___________/
#
#
# YOUR PREDICTION IS WRONG! COMPUTER_2 IS THE LOSER!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c9609a09d645> in <cell line: 103>()
#     101
#     102 game = jyankenpoi()
# --> 103 game.play_game()
#
# <ipython-input-1-c9609a09d645> in play_game(self)
#      95                 print(text_2.upper())
#      96
# ---> 97             play_again = input("Do you want to play again? (yes/no): ").lower()
#      98             if play_again != "yes":
#      99                 print("Thanks for playing!")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
